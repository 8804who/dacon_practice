# %% [markdown]
# ## Import

# %%
import random
import pandas as pd
import numpy as np
import os
from tqdm.auto import tqdm
import librosa

from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler 

import warnings
warnings.filterwarnings(action='ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Hyperparameter Setting

# %%
CFG = {
    'SR':20000,
    'N_MFCC':40, # Melspectrogram 벡터를 추출할 개수
    'SEED':42
}

# %% [markdown]
# ## Fixed Random-Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# ## Data Pre-Processing

# %%
train_df = pd.read_csv('/content/drive/MyDrive/speech_emotion/data/train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/speech_emotion/data/test.csv')

train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state=CFG['SEED'])

# %%
def get_mfcc_feature(df):
    features = []
    for path in tqdm(df['path']):
        # librosa패키지를 사용하여 wav 파일 load
        y, sr = librosa.load('/content/drive/MyDrive/speech_emotion/data/'+path[2:], sr=CFG['SR'])
        y = librosa.util.fix_length(y, size=40000)
        # librosa패키지를 사용하여 mfcc 추출
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=CFG['N_MFCC'])
        features.append(mfcc)
        
    features = np.array(features, np.float32)
    return features

# %%
train_x = get_mfcc_feature(train_df)
valid_x = get_mfcc_feature(valid_df)
test_x = get_mfcc_feature(test_df)
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
#   0%|          | 0/1001 [00:00<?, ?it/s]
#   0%|          | 0/1881 [00:00<?, ?it/s]

# %%
print(train_x.shape)
print(valid_x.shape)
print(test_x.shape)
# Out:
# (4000, 40, 79)
# (1001, 40, 79)
# (1881, 40, 79)

# %%
train_x = train_x.reshape((4000, -1))
valid_x = valid_x.reshape((1001, -1))
test_x = test_x.reshape((1881, -1))

# %%
scaler = MinMaxScaler()
scaler.fit(train_x)

valid_scaler = MinMaxScaler()
scaler.fit(valid_x)

test_scaler = MinMaxScaler()
scaler.fit(test_x)
# Out:
# MinMaxScaler()

# %%
train_y = np.array(train_df['label'])
valid_y = np.array(valid_df['label'])

# %% [markdown]
# ## Classification Model Fit

# %%
SVM = svm.SVC(kernel = 'linear')
SVM.fit(train_x, train_y)
# Out:
# SVC(kernel='linear')

# %%
valid_pred = SVM.predict(valid_x)
print('Accuracy: %.2f' % accuracy_score(valid_y, valid_pred))
# Out:
# Accuracy: 0.38

# %% [markdown]
# ## Inference

# %%
preds = model.predict(test_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-125163a4a627> in <cell line: 1>()
# ----> 1 preds = model.predict(test_x)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv('./sample_submission.csv')
submission['label'] = preds
submission.to_csv('./baseline_submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 submission = pd.read_csv('./sample_submission.csv')
#       2 submission['label'] = preds
#       3 submission.to_csv('./baseline_submission.csv', index=False)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /opt/conda/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample_submission.csv'
