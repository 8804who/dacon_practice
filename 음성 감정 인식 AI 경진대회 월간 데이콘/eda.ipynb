# %%
import librosa
import librosa.display as dsp
from IPython.display import Audio
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(42)

# %%
train = pd.read_csv('../data/train.csv')
train_gender = pd.read_csv('../data/train_gender.csv')

# %%
audio_len = []

for path in train.path:
    data, sample_rate = librosa.load('../data/'+path[2:], sr=16000)
    data, _ = librosa.effects.trim(data, top_db=40)
    audio_len.append(data.shape[0]/float(sample_rate))

# %%
sns.distplot(audio_len)
# Out:
# /tmp/ipykernel_6060/698645183.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(audio_len)
# <Axes: ylabel='Density'>

# %%
def get_audio(datas, label):
    # Audio Sample Directory
    #num = int(random.uniform(0,5000))
    for data in datas.iloc[:10].itertuples():
        if data.label==label:
            audio, sample_rate = librosa.load('../data/'+data.path[2:], sr=16000)
            audio, _ = librosa.effects.trim(audio, top_db=30, frame_length=400, hop_length=160)
    
    # Plot the audio wave
    dsp.waveshow(audio,sr=sample_rate)
    plt.show()
    
    # Show the widget
    return Audio(data=audio,rate=sample_rate)

# %%
#0:angry 1:fear 2:sad 3:disgust 4:neutral 5:happy
get_audio(train, 1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mfccs=[]
for data in train.itertuples():
    audio, sample_rate = librosa.load('../data/'+data.path[2:], sr=16000)
    audio = librosa.util.fix_length(audio, 80000)
    
    mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    y_feature = []
    # 추출된 MFCC들의 평균을 Feature로 사용
    for e in mfcc:
        y_feature.append(np.mean(e))
    mfccs.append(y_feature)


mfcc_df = pd.DataFrame(mfccs, columns=['mfcc_'+str(x) for x in range(1,41)])
mfcc_df.to_csv('../data/mfccs.csv')
# Out:
# /tmp/ipykernel_6060/1189723752.py:4: FutureWarning: Pass size=80000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   audio = librosa.util.fix_length(audio, 80000)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 6
#       3 audio, sample_rate = librosa.load('../data/'+data.path[2:], sr=16000)
#       4 audio = librosa.util.fix_length(audio, 80000)
# ----> 6 mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
#       7 y_feature = []
#       8 # 추출된 MFCC들의 평균을 Feature로 사용
#
# File /opt/conda/lib/python3.8/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File /opt/conda/lib/python3.8/site-packages/librosa/feature/spectral.py:1903, in mfcc(y, sr, S, n_mfcc, dct_type, norm, lifter, **kwargs)
#    1784 """Mel-frequency cepstral coefficients (MFCCs)
#    1785
#    1786 .. warning:: If multi-channel audio input ``y`` is provided, the MFCC
#    (...)
#    1898 >>> fig.colorbar(img2, ax=[ax[1]])
#    1899 """
#    1901 if S is None:
#    1902     # multichannel behavior may be different due to relative noise floor differences between channels
# -> 1903     S = power_to_db(melspectrogram(y=y, sr=sr, **kwargs))
#    1905 M = scipy.fftpack.dct(S, axis=-2, type=dct_type, norm=norm)[..., :n_mfcc, :]
#    1907 if lifter > 0:
#    1908     # shape lifter for broadcasting
#
# File /opt/conda/lib/python3.8/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File /opt/conda/lib/python3.8/site-packages/librosa/feature/spectral.py:2043, in melspectrogram(y, sr, S, n_fft, hop_length, win_length, window, center, pad_mode, power, **kwargs)
#    1922 @deprecate_positional_args
#    1923 def melspectrogram(
#    1924     *,
#    (...)
#    1935     **kwargs,
#    1936 ):
#    1937     """Compute a mel-scaled spectrogram.
#    1938
#    1939     If a spectrogram input ``S`` is provided, then it is mapped directly onto
#    (...)
#    2040     >>> ax.set(title='Mel-frequency spectrogram')
#    2041     """
# -> 2043     S, n_fft = _spectrogram(
#    2044         y=y,
#    2045         S=S,
#    2046         n_fft=n_fft,
#    2047         hop_length=hop_length,
#    2048         power=power,
#    2049         win_length=win_length,
#    2050         window=window,
#    2051         center=center,
#    2052         pad_mode=pad_mode,
#    2053     )
#    2055     # Build a Mel filter
#    2056     mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/librosa/core/spectrum.py:2564, in _spectrogram(y, S, n_fft, hop_length, power, win_length, window, center, pad_mode)
#    2559         n_fft = 2 * (S.shape[-2] - 1)
#    2560 else:
#    2561     # Otherwise, compute a magnitude spectrogram from input
#    2562     S = (
#    2563         np.abs(
# -> 2564             stft(
#    2565                 y,
#    2566                 n_fft=n_fft,
#    2567                 hop_length=hop_length,
#    2568                 win_length=win_length,
#    2569                 center=center,
#    2570                 window=window,
#    2571                 pad_mode=pad_mode,
#    2572             )
#    2573         )
#    2574         ** power
#    2575     )
#    2577 return S, n_fft
#
# File /opt/conda/lib/python3.8/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File /opt/conda/lib/python3.8/site-packages/librosa/core/spectrum.py:254, in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     251 for bl_s in range(0, stft_matrix.shape[-1], n_columns):
#     252     bl_t = min(bl_s + n_columns, stft_matrix.shape[-1])
# --> 254     stft_matrix[..., bl_s:bl_t] = fft.rfft(
#     255         fft_window * y_frames[..., bl_s:bl_t], axis=-2
#     256     )
#     257 return stft_matrix
#
# File <__array_function__ internals>:180, in rfft(*args, **kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/numpy/fft/_pocketfft.py:409, in rfft(a, n, axis, norm)
#     407     n = a.shape[axis]
#     408 inv_norm = _get_forward_norm(n, norm)
# --> 409 output = _raw_fft(a, n, axis, True, True, inv_norm)
#     410 return output
#
# File /opt/conda/lib/python3.8/site-packages/numpy/fft/_pocketfft.py:73, in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      71 else:
#      72     a = swapaxes(a, axis, -1)
# ---> 73     r = pfi.execute(a, is_real, is_forward, fct)
#      74     r = swapaxes(r, axis, -1)
#      75 return r
#
# KeyboardInterrupt:
